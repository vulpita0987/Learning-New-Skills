# %%
import requests
import pandas as pd

def get_all_rickmorty_characters():
    url = "https://rickandmortyapi.com/api/character"
    characters = []

    while url:
        response = requests.get(url).json()
        for c in response["results"]:
            characters.append({
                "id": c["id"],
                "name": c["name"],
                "status": c["status"],
                "species": c["species"],
                "type": c["type"],
                "gender": c["gender"],
                "origin": c["origin"]["name"],
                "location": c["location"]["name"],
                "image": c["image"],
                "episode_count": len(c["episode"])
            })
        url = response["info"]["next"]  # pagination

    return pd.DataFrame(characters)

characters_df = get_all_rickmorty_characters()
characters_df.head()
# Out:
#    id          name status species type  gender  \
# 0   1  Rick Sanchez  Alive   Human         Male
# 1   2   Morty Smith  Alive   Human         Male
# 2   3  Summer Smith  Alive   Human       Female
# 3   4    Beth Smith  Alive   Human       Female
# 4   5   Jerry Smith  Alive   Human         Male
#
#                           origin                       location  \
# 0                  Earth (C-137)               Citadel of Ricks
# 1                        unknown               Citadel of Ricks
# 2  Earth (Replacement Dimension)  Earth (Replacement Dimension)
# 3  Earth (Replacement Dimension)  Earth (Replacement Dimension)
# 4  Earth (Replacement Dimension)  Earth (Replacement Dimension)
#
#                                                image  episode_count
# 0  https://rickandmortyapi.com/api/character/avat...             51
# 1  https://rickandmortyapi.com/api/character/avat...             51
# 2  https://rickandmortyapi.com/api/character/avat...             42
# 3  https://rickandmortyapi.com/api/character/avat...             42
# 4  https://rickandmortyapi.com/api/character/avat...             39

# %%
def get_all_rickmorty_episodes():
    url = "https://rickandmortyapi.com/api/episode"
    episodes = []

    while url:
        response = requests.get(url).json()
        for e in response["results"]:
            episodes.append({
                "id": e["id"],
                "name": e["name"],
                "air_date": e["air_date"],
                "episode_code": e["episode"],
                "character_count": len(e["characters"])
            })
        url = response["info"]["next"]

    return pd.DataFrame(episodes)

episodes_df = get_all_rickmorty_episodes()
episodes_df.head()
# Out:
#    id                    name           air_date episode_code  character_count
# 0   1                   Pilot   December 2, 2013       S01E01               19
# 1   2           Lawnmower Dog   December 9, 2013       S01E02               19
# 2   3            Anatomy Park  December 16, 2013       S01E03               24
# 3   4  M. Night Shaym-Aliens!   January 13, 2014       S01E04               13
# 4   5    Meeseeks and Destroy   January 20, 2014       S01E05               20

# %%
def get_all_rickmorty_locations():
    url = "https://rickandmortyapi.com/api/location"
    locations = []

    while url:
        response = requests.get(url).json()
        for l in response["results"]:
            locations.append({
                "id": l["id"],
                "name": l["name"],
                "type": l["type"],
                "dimension": l["dimension"],
                "resident_count": len(l["residents"])
            })
        url = response["info"]["next"]

    return pd.DataFrame(locations)

locations_df = get_all_rickmorty_locations()
locations_df.head()
# Out:
#    id               name           type        dimension  resident_count
# 0   1      Earth (C-137)         Planet  Dimension C-137              27
# 1   2           Abadango        Cluster          unknown               1
# 2   3   Citadel of Ricks  Space station          unknown             101
# 3   4  Worldender's lair         Planet          unknown               9
# 4   5       Anatomy Park     Microverse  Dimension C-137              11

# %%
with pd.ExcelWriter("13.Rick and Morty API Data.xlsx") as writer:
    characters_df.to_excel(writer, sheet_name="Characters", index=False)
    episodes_df.to_excel(writer, sheet_name="Episodes", index=False)
    locations_df.to_excel(writer, sheet_name="Locations", index=False)

# %%
import sqlite3

conn = sqlite3.connect(":memory:")  # temporary SQL database in RAM

characters_df.to_sql("characters", conn, index=False, if_exists="replace")
episodes_df.to_sql("episodes", conn, index=False, if_exists="replace")
locations_df.to_sql("locations", conn, index=False, if_exists="replace")
# Out:
# 126

# %%
query = """
SELECT 
    c.id AS character_id,
    c.name AS character_name,
    c.status,
    c.species,
    c.type,
    c.gender,
    c.episode_count,

    -- origin info
    o.id AS origin_id,
    o.type AS origin_type,
    o.dimension AS origin_dimension,

    -- current location info
    l.id AS location_id,
    l.type AS location_type,
    l.dimension AS location_dimension

FROM characters c
LEFT JOIN locations o ON c.origin = o.name
LEFT JOIN locations l ON c.location = l.name
"""

# %%
merged_df = pd.read_sql_query(query, conn)
merged_df.head()
# Out:
#    character_id character_name status species type  gender  episode_count  \
# 0             1   Rick Sanchez  Alive   Human         Male             51
# 1             2    Morty Smith  Alive   Human         Male             51
# 2             3   Summer Smith  Alive   Human       Female             42
# 3             4     Beth Smith  Alive   Human       Female             42
# 4             5    Jerry Smith  Alive   Human         Male             39
#
#    origin_id origin_type       origin_dimension  location_id  location_type  \
# 0        1.0      Planet        Dimension C-137          3.0  Space station
# 1        NaN        None                   None          3.0  Space station
# 2       20.0      Planet  Replacement Dimension         20.0         Planet
# 3       20.0      Planet  Replacement Dimension         20.0         Planet
# 4       20.0      Planet  Replacement Dimension         20.0         Planet
#
#       location_dimension
# 0                unknown
# 1                unknown
# 2  Replacement Dimension
# 3  Replacement Dimension
# 4  Replacement Dimension

# %%
merged_df
# Out:
#      character_id character_name   status species                  type  \
# 0               1   Rick Sanchez    Alive   Human
# 1               2    Morty Smith    Alive   Human
# 2               3   Summer Smith    Alive   Human
# 3               4     Beth Smith    Alive   Human
# 4               5    Jerry Smith    Alive   Human
# ..            ...            ...      ...     ...                   ...
# 821           822    Young Jerry  unknown   Human
# 822           823     Young Beth  unknown   Human
# 823           824     Young Beth  unknown   Human
# 824           825    Young Jerry  unknown   Human
# 825           826   Butter Robot    Alive   Robot  Passing Butter Robot
#
#          gender  episode_count  origin_id origin_type       origin_dimension  \
# 0          Male             51        1.0      Planet        Dimension C-137
# 1          Male             51        NaN        None                   None
# 2        Female             42       20.0      Planet  Replacement Dimension
# 3        Female             42       20.0      Planet  Replacement Dimension
# 4          Male             39       20.0      Planet  Replacement Dimension
# ..          ...            ...        ...         ...                    ...
# 821        Male              1       30.0      Planet                unknown
# 822      Female              1       30.0      Planet                unknown
# 823      Female              1       30.0      Planet                unknown
# 824        Male              1       30.0      Planet                unknown
# 825  Genderless              1       20.0      Planet  Replacement Dimension
#
#      location_id  location_type     location_dimension
# 0            3.0  Space station                unknown
# 1            3.0  Space station                unknown
# 2           20.0         Planet  Replacement Dimension
# 3           20.0         Planet  Replacement Dimension
# 4           20.0         Planet  Replacement Dimension
# ..           ...            ...                    ...
# 821         30.0         Planet                unknown
# 822         30.0         Planet                unknown
# 823         30.0         Planet                unknown
# 824         30.0         Planet                unknown
# 825         20.0         Planet  Replacement Dimension
#
# [826 rows x 13 columns]

# %%
merged = (
    characters_df
    .merge(episodes_df, on="id")
    .merge(locations_df, on="id")
)

# %%
merged
# Out:
#     id                     name_x   status                species  \
# 0    1               Rick Sanchez    Alive                  Human
# 1    2                Morty Smith    Alive                  Human
# 2    3               Summer Smith    Alive                  Human
# 3    4                 Beth Smith    Alive                  Human
# 4    5                Jerry Smith    Alive                  Human
# 5    6  Abadango Cluster Princess    Alive                  Alien
# 6    7           Abradolf Lincler  unknown                  Human
# 7    8           Adjudicator Rick     Dead                  Human
# 8    9            Agency Director     Dead                  Human
# 9   10                 Alan Rails     Dead                  Human
# 10  11            Albert Einstein     Dead                  Human
# 11  12                  Alexander     Dead                  Human
# 12  13               Alien Googah  unknown                  Alien
# 13  14                Alien Morty  unknown                  Alien
# 14  15                 Alien Rick  unknown                  Alien
# 15  16               Amish Cyborg     Dead                  Alien
# 16  17                      Annie    Alive                  Human
# 17  18              Antenna Morty    Alive                  Human
# 18  19               Antenna Rick  unknown                  Human
# 19  20    Ants in my Eyes Johnson  unknown                  Human
# 20  21                 Aqua Morty  unknown               Humanoid
# 21  22                  Aqua Rick  unknown               Humanoid
# 22  23               Arcade Alien  unknown                  Alien
# 23  24                Armagheadon    Alive                  Alien
# 24  25                    Armothy     Dead                unknown
# 25  26                  Arthricia    Alive                  Alien
# 26  27               Artist Morty    Alive                  Human
# 27  28             Attila Starwar    Alive                  Human
# 28  29                  Baby Legs    Alive                  Human
# 29  30         Baby Poopybutthole    Alive          Poopybutthole
# 30  31                Baby Wizard     Dead                  Alien
# 31  32               Bearded Lady     Dead                  Alien
# 32  33                      Beebo     Dead                  Alien
# 33  34                   Benjamin    Alive          Poopybutthole
# 34  35                   Bepisian    Alive                  Alien
# 35  36                 Beta-Seven    Alive                  Alien
# 36  37               Beth Sanchez    Alive                  Human
# 37  38                 Beth Smith    Alive                  Human
# 38  39                 Beth Smith    Alive                  Human
# 39  40            Beth's Mytholog     Dead  Mythological Creature
# 40  41        Big Boobed Waitress    Alive  Mythological Creature
# 41  42             Big Head Morty  unknown                  Human
# 42  43                  Big Morty     Dead                  Human
# 43  44           Body Guard Morty     Dead                  Human
# 44  45                       Bill    Alive                  Human
# 45  46                       Bill  unknown                 Animal
# 46  47                 Birdperson    Alive                  Alien
# 47  48                 Black Rick    Alive                  Human
# 48  49                     Blamph    Alive                  Alien
# 49  50                  Blim Blam    Alive                  Alien
# 50  51              Blue Diplomat    Alive                  Alien
#
#                                 type_x   gender  \
# 0                                          Male
# 1                                          Male
# 2                                        Female
# 3                                        Female
# 4                                          Male
# 5                                        Female
# 6                   Genetic experiment     Male
# 7                                          Male
# 8                                          Male
# 9   Superhuman (Ghost trains summoner)     Male
# 10                                         Male
# 11                                         Male
# 12                                      unknown
# 13                                         Male
# 14                                         Male
# 15                            Parasite     Male
# 16                                       Female
# 17                 Human with antennae     Male
# 18                 Human with antennae     Male
# 19         Human with ants in his eyes     Male
# 20                         Fish-Person     Male
# 21                         Fish-Person     Male
# 22                                         Male
# 23                            Cromulon     Male
# 24                      Self-aware arm     Male
# 25                          Cat-Person   Female
# 26                                         Male
# 27                                         Male
# 28                Human with baby legs     Male
# 29                                         Male
# 30                            Parasite     Male
# 31                            Parasite   Female
# 32                                         Male
# 33                                         Male
# 34                            Bepisian  unknown
# 35                            Hivemind  unknown
# 36                                       Female
# 37                                       Female
# 38                                       Female
# 39                            Mytholog   Female
# 40                                       Female
# 41               Human with giant head     Male
# 42                                         Male
# 43                                         Male
# 44                                         Male
# 45                                 Dog     Male
# 46                         Bird-Person     Male
# 47                                         Male
# 48                                      unknown
# 49                            Korblock     Male
# 50                                         Male
#
#                                   origin  \
# 0                          Earth (C-137)
# 1                                unknown
# 2          Earth (Replacement Dimension)
# 3          Earth (Replacement Dimension)
# 4          Earth (Replacement Dimension)
# 5                               Abadango
# 6          Earth (Replacement Dimension)
# 7                                unknown
# 8          Earth (Replacement Dimension)
# 9                                unknown
# 10                         Earth (C-137)
# 11                         Earth (C-137)
# 12                               unknown
# 13                               unknown
# 14                               unknown
# 15                               unknown
# 16                         Earth (C-137)
# 17                               unknown
# 18                               unknown
# 19                               unknown
# 20                               unknown
# 21                               unknown
# 22                               unknown
# 23                      Signus 5 Expanse
# 24                Post-Apocalyptic Earth
# 25                          Purge Planet
# 26                               unknown
# 27                               unknown
# 28                               unknown
# 29                               unknown
# 30                               unknown
# 31                               unknown
# 32                          Venzenulon 7
# 33                               unknown
# 34                               Bepis 9
# 35                               unknown
# 36                        Earth (C-500A)
# 37                         Earth (C-137)
# 38  Earth (Evil Rick's Target Dimension)
# 39                              Nuptia 4
# 40                         Fantasy World
# 41                               unknown
# 42                               unknown
# 43                               unknown
# 44                         Earth (C-137)
# 45         Earth (Replacement Dimension)
# 46                            Bird World
# 47                               unknown
# 48                               unknown
# 49                               unknown
# 50                               unknown
#
#                                 location  \
# 0                       Citadel of Ricks
# 1                       Citadel of Ricks
# 2          Earth (Replacement Dimension)
# 3          Earth (Replacement Dimension)
# 4          Earth (Replacement Dimension)
# 5                               Abadango
# 6             Testicle Monster Dimension
# 7                       Citadel of Ricks
# 8          Earth (Replacement Dimension)
# 9                      Worldender's lair
# 10         Earth (Replacement Dimension)
# 11                          Anatomy Park
# 12         Earth (Replacement Dimension)
# 13                      Citadel of Ricks
# 14                      Citadel of Ricks
# 15         Earth (Replacement Dimension)
# 16                          Anatomy Park
# 17                      Citadel of Ricks
# 18                               unknown
# 19                Interdimensional Cable
# 20                      Citadel of Ricks
# 21                      Citadel of Ricks
# 22              Immortality Field Resort
# 23                      Signus 5 Expanse
# 24                Post-Apocalyptic Earth
# 25                          Purge Planet
# 26                      Citadel of Ricks
# 27                Interdimensional Cable
# 28                Interdimensional Cable
# 29                               unknown
# 30         Earth (Replacement Dimension)
# 31         Earth (Replacement Dimension)
# 32                          Venzenulon 7
# 33                Interdimensional Cable
# 34                               Bepis 9
# 35                               unknown
# 36                        Earth (C-500A)
# 37                         Earth (C-137)
# 38  Earth (Evil Rick's Target Dimension)
# 39                              Nuptia 4
# 40                         Fantasy World
# 41                      Citadel of Ricks
# 42                      Citadel of Ricks
# 43                      Citadel of Ricks
# 44                         Earth (C-137)
# 45                               unknown
# 46                        Planet Squanch
# 47                      Citadel of Ricks
# 48                Interdimensional Cable
# 49         Earth (Replacement Dimension)
# 50                Interdimensional Cable
#
#                                                 image  episode_count  \
# 0   https://rickandmortyapi.com/api/character/avat...             51
# 1   https://rickandmortyapi.com/api/character/avat...             51
# 2   https://rickandmortyapi.com/api/character/avat...             42
# 3   https://rickandmortyapi.com/api/character/avat...             42
# 4   https://rickandmortyapi.com/api/character/avat...             39
# 5   https://rickandmortyapi.com/api/character/avat...              1
# 6   https://rickandmortyapi.com/api/character/avat...              2
# 7   https://rickandmortyapi.com/api/character/avat...              1
# 8   https://rickandmortyapi.com/api/character/avat...              1
# 9   https://rickandmortyapi.com/api/character/avat...              1
# 10  https://rickandmortyapi.com/api/character/avat...              1
# 11  https://rickandmortyapi.com/api/character/avat...              1
# 12  https://rickandmortyapi.com/api/character/avat...              1
# 13  https://rickandmortyapi.com/api/character/avat...              1
# 14  https://rickandmortyapi.com/api/character/avat...              1
# 15  https://rickandmortyapi.com/api/character/avat...              1
# 16  https://rickandmortyapi.com/api/character/avat...              1
# 17  https://rickandmortyapi.com/api/character/avat...              2
# 18  https://rickandmortyapi.com/api/character/avat...              1
# 19  https://rickandmortyapi.com/api/character/avat...              1
# 20  https://rickandmortyapi.com/api/character/avat...              2
# 21  https://rickandmortyapi.com/api/character/avat...              3
# 22  https://rickandmortyapi.com/api/character/avat...              5
# 23  https://rickandmortyapi.com/api/character/avat...              1
# 24  https://rickandmortyapi.com/api/character/avat...              1
# 25  https://rickandmortyapi.com/api/character/avat...              1
# 26  https://rickandmortyapi.com/api/character/avat...              2
# 27  https://rickandmortyapi.com/api/character/avat...              3
# 28  https://rickandmortyapi.com/api/character/avat...              1
# 29  https://rickandmortyapi.com/api/character/avat...              1
# 30  https://rickandmortyapi.com/api/character/avat...              1
# 31  https://rickandmortyapi.com/api/character/avat...              1
# 32  https://rickandmortyapi.com/api/character/avat...              1
# 33  https://rickandmortyapi.com/api/character/avat...              3
# 34  https://rickandmortyapi.com/api/character/avat...              4
# 35  https://rickandmortyapi.com/api/character/avat...              1
# 36  https://rickandmortyapi.com/api/character/avat...              1
# 37  https://rickandmortyapi.com/api/character/avat...              8
# 38  https://rickandmortyapi.com/api/character/avat...              1
# 39  https://rickandmortyapi.com/api/character/avat...              1
# 40  https://rickandmortyapi.com/api/character/avat...              1
# 41  https://rickandmortyapi.com/api/character/avat...              1
# 42  https://rickandmortyapi.com/api/character/avat...              1
# 43  https://rickandmortyapi.com/api/character/avat...              1
# 44  https://rickandmortyapi.com/api/character/avat...              1
# 45  https://rickandmortyapi.com/api/character/avat...              1
# 46  https://rickandmortyapi.com/api/character/avat...              7
# 47  https://rickandmortyapi.com/api/character/avat...              2
# 48  https://rickandmortyapi.com/api/character/avat...              1
# 49  https://rickandmortyapi.com/api/character/avat...              1
# 50  https://rickandmortyapi.com/api/character/avat...              1
#
#                                          name_y            air_date  \
# 0                                         Pilot    December 2, 2013
# 1                                 Lawnmower Dog    December 9, 2013
# 2                                  Anatomy Park   December 16, 2013
# 3                        M. Night Shaym-Aliens!    January 13, 2014
# 4                          Meeseeks and Destroy    January 20, 2014
# 5                                Rick Potion #9    January 27, 2014
# 6                           Raising Gazorpazorp      March 10, 2014
# 7                                 Rixty Minutes      March 17, 2014
# 8               Something Ricked This Way Comes      March 24, 2014
# 9          Close Rick-counters of the Rick Kind       April 7, 2014
# 10                              Ricksy Business      April 14, 2014
# 11                             A Rickle in Time       July 26, 2015
# 12                               Mortynight Run      August 2, 2015
# 13                     Auto Erotic Assimilation      August 9, 2015
# 14                                Total Rickall     August 16, 2015
# 15                                 Get Schwifty     August 23, 2015
# 16                      The Ricks Must Be Crazy     August 30, 2015
# 17                Big Trouble in Little Sanchez  September 13, 2015
# 18      Interdimensional Cable 2: Tempting Fate  September 20, 2015
# 19                       Look Who's Purging Now  September 27, 2015
# 20                       The Wedding Squanchers     October 4, 2015
# 21                   The Rickshank Rickdemption       April 1, 2017
# 22                        Rickmancing the Stone       July 30, 2017
# 23                                  Pickle Rick      August 6, 2017
# 24      Vindicators 3: The Return of Worldender     August 13, 2017
# 25                  The Whirly Dirly Conspiracy     August 20, 2017
# 26                        Rest and Ricklaxation     August 27, 2017
# 27                         The Ricklantis Mixup  September 10, 2017
# 28                         Morty's Mind Blowers  September 17, 2017
# 29                            The ABC's of Beth  September 24, 2017
# 30                    The Rickchurian Mortydate     October 1, 2017
# 31         Edge of Tomorty: Rick, Die, Rickpeat   November 10, 2019
# 32                     The Old Man and the Seat   November 17, 2019
# 33            One Crew Over the Crewcoo's Morty   November 24, 2019
# 34    Claw and Hoarder: Special Ricktim's Morty    December 8, 2019
# 35                       Rattlestar Ricklactica   December 15, 2019
# 36                          Never Ricking Morty         May 3, 2020
# 37                                   Promortyus        May 10, 2020
# 38                      The Vat of Acid Episode        May 17, 2020
# 39                            Childrick of Mort        May 24, 2020
# 40             Star Mort: Rickturn of the Jerri        May 31, 2020
# 41                       Mort Dinner Rick Andre       June 20, 2021
# 42                                 Mortyplicity       June 27, 2021
# 43                        A Rickconvenient Mort        July 4, 2021
# 44                         Rickdependence Spray       July 11, 2021
# 45                         Amortycan Grickfitti       July 18, 2021
# 46  Rick & Morty's Thanksploitation Spectacular       July 25, 2021
# 47                Gotron Jerrysis Rickvangelion      August 1, 2021
# 48  Rickternal Friendshine of the Spotless Mort      August 8, 2021
# 49                  Forgetting Sarick Mortshall   September 5, 2021
# 50                               Rickmurai Jack   September 5, 2021
#
#    episode_code  character_count                                        name  \
# 0        S01E01               19                               Earth (C-137)
# 1        S01E02               19                                    Abadango
# 2        S01E03               24                            Citadel of Ricks
# 3        S01E04               13                           Worldender's lair
# 4        S01E05               20                                Anatomy Park
# 5        S01E06               24                      Interdimensional Cable
# 6        S01E07               14                    Immortality Field Resort
# 7        S01E08               57                      Post-Apocalyptic Earth
# 8        S01E09               17                                Purge Planet
# 9        S01E10               60                                Venzenulon 7
# 10       S01E11               30                                     Bepis 9
# 11       S02E01               13                            Cronenberg Earth
# 12       S02E02               36                                    Nuptia 4
# 13       S02E03               14                                Giant's Town
# 14       S02E04               24                                  Bird World
# 15       S02E05               31                   St. Gloopy Noops Hospital
# 16       S02E06               19                               Earth (5-126)
# 17       S02E07               26                      Mr. Goldenfold's dream
# 18       S02E08               40                              Gromflom Prime
# 19       S02E09               10               Earth (Replacement Dimension)
# 20       S02E10               29                  Testicle Monster Dimension
# 21       S03E01               44                            Signus 5 Expanse
# 22       S03E02               18                              Earth (C-500A)
# 23       S03E03               15                   Rick's Battery Microverse
# 24       S03E04               30                               The Menagerie
# 25       S03E05               21                                Earth (K-83)
# 26       S03E06               19                              Hideout Planet
# 27       S03E07               65                              Unity's Planet
# 28       S03E08               20                                    Dorian 5
# 29       S03E09               18                   Earth (Unknown dimension)
# 30       S03E10               14                               Earth (J19ζ7)
# 31       S04E01               38                      Roy: A Life Well Lived
# 32       S04E02               24                      Eric Stoltz Mask Earth
# 33       S04E03               23        Earth (Evil Rick's Target Dimension)
# 34       S04E04               14                              Planet Squanch
# 35       S04E05               29                                Glaagablaaga
# 36       S04E06               49                               Resort Planet
# 37       S04E07               14                    Interdimensional Customs
# 38       S04E08               21                  Galactic Federation Prison
# 39       S04E09               10                                 Gazorpazorp
# 40       S04E10               13                       Hamster in Butt World
# 41       S05E01               21  Earth (Giant Telepathic Spiders Dimension)
# 42       S05E02               37                                Alphabetrium
# 43       S05E03               17                                  Jerryboree
# 44       S05E04               23                                 Krootabulon
# 45       S05E05               18                             Zigerion's Base
# 46       S05E06               23                                       Pluto
# 47       S05E07               21                               Fantasy World
# 48       S05E08               16                   Zeep Xanflorp's Miniverse
# 49       S05E09               10                           Kyle's Teenyverse
# 50       S05E10               42                        Larva Alien's Planet
#
#                             type_y                           dimension  \
# 0                           Planet                     Dimension C-137
# 1                          Cluster                             unknown
# 2                    Space station                             unknown
# 3                           Planet                             unknown
# 4                       Microverse                     Dimension C-137
# 5                               TV                             unknown
# 6                           Resort                             unknown
# 7                           Planet          Post-Apocalyptic Dimension
# 8                           Planet               Replacement Dimension
# 9                           Planet                             unknown
# 10                          Planet                             unknown
# 11                          Planet                Cronenberg Dimension
# 12                          Planet                             unknown
# 13                    Fantasy town                   Fantasy Dimension
# 14                          Planet                             unknown
# 15                   Space station                             unknown
# 16                          Planet                     Dimension 5-126
# 17                           Dream                     Dimension C-137
# 18                          Planet               Replacement Dimension
# 19                          Planet               Replacement Dimension
# 20                       Dimension          Testicle Monster Dimension
# 21                         unknown                  Cromulon Dimension
# 22                          Planet                    Dimension C-500A
# 23                      Microverse               Replacement Dimension
# 24                       Menagerie                             unknown
# 25                          Planet                      Dimension K-83
# 26                          Planet                             unknown
# 27                          Planet               Replacement Dimension
# 28                          Planet               Replacement Dimension
# 29                          Planet                             unknown
# 30                          Planet                     Dimension J19ζ7
# 31                            Game               Replacement Dimension
# 32                          Planet          Eric Stoltz Mask Dimension
# 33                          Planet        Evil Rick's Target Dimension
# 34                          Planet               Replacement Dimension
# 35                          Planet                             unknown
# 36                          Planet                             unknown
# 37                         Customs                             unknown
# 38                   Space station                             unknown
# 39                          Planet                             unknown
# 40                          Planet                             unknown
# 41                          Planet  Giant Telepathic Spiders Dimension
# 42                          Planet               Replacement Dimension
# 43                         Daycare                             unknown
# 44                          Planet               Replacement Dimension
# 45                   Space station                     Dimension C-137
# 46  Dwarf planet (Celestial Dwarf)               Replacement Dimension
# 47                          Planet                   Fantasy Dimension
# 48                       Miniverse               Replacement Dimension
# 49                      Teenyverse               Replacement Dimension
# 50                          Planet                   Unknown dimension
#
#     resident_count
# 0               27
# 1                1
# 2              101
# 3                9
# 4               11
# 5               62
# 6                3
# 7               10
# 8                4
# 9                1
# 10               1
# 11               0
# 12              11
# 13               3
# 14               0
# 15               9
# 16               0
# 17               8
# 18               0
# 19             230
# 20               2
# 21               2
# 22               5
# 23               2
# 24               3
# 25               0
# 26               2
# 27               6
# 28               3
# 29               4
# 30               0
# 31               5
# 32               0
# 33               5
# 34              11
# 35               0
# 36               5
# 37               2
# 38               1
# 39               3
# 40               1
# 41               2
# 42               5
# 43               8
# 44               0
# 45               4
# 46               6
# 47               4
# 48               1
# 49               2
# 50               0

# %%
merged1 = (
    characters_df
    .merge(locations_df.add_prefix("origin_"), left_on="origin", right_on="origin_name", how="left")
    .merge(locations_df.add_prefix("loc_"), left_on="location", right_on="loc_name", how="left")
)

# %%
merged1
# Out:
#       id          name   status species                  type      gender  \
# 0      1  Rick Sanchez    Alive   Human                              Male
# 1      2   Morty Smith    Alive   Human                              Male
# 2      3  Summer Smith    Alive   Human                            Female
# 3      4    Beth Smith    Alive   Human                            Female
# 4      5   Jerry Smith    Alive   Human                              Male
# ..   ...           ...      ...     ...                   ...         ...
# 821  822   Young Jerry  unknown   Human                              Male
# 822  823    Young Beth  unknown   Human                            Female
# 823  824    Young Beth  unknown   Human                            Female
# 824  825   Young Jerry  unknown   Human                              Male
# 825  826  Butter Robot    Alive   Robot  Passing Butter Robot  Genderless
#
#                             origin                       location  \
# 0                    Earth (C-137)               Citadel of Ricks
# 1                          unknown               Citadel of Ricks
# 2    Earth (Replacement Dimension)  Earth (Replacement Dimension)
# 3    Earth (Replacement Dimension)  Earth (Replacement Dimension)
# 4    Earth (Replacement Dimension)  Earth (Replacement Dimension)
# ..                             ...                            ...
# 821      Earth (Unknown dimension)      Earth (Unknown dimension)
# 822      Earth (Unknown dimension)      Earth (Unknown dimension)
# 823      Earth (Unknown dimension)      Earth (Unknown dimension)
# 824      Earth (Unknown dimension)      Earth (Unknown dimension)
# 825  Earth (Replacement Dimension)  Earth (Replacement Dimension)
#
#                                                  image  episode_count  \
# 0    https://rickandmortyapi.com/api/character/avat...             51
# 1    https://rickandmortyapi.com/api/character/avat...             51
# 2    https://rickandmortyapi.com/api/character/avat...             42
# 3    https://rickandmortyapi.com/api/character/avat...             42
# 4    https://rickandmortyapi.com/api/character/avat...             39
# ..                                                 ...            ...
# 821  https://rickandmortyapi.com/api/character/avat...              1
# 822  https://rickandmortyapi.com/api/character/avat...              1
# 823  https://rickandmortyapi.com/api/character/avat...              1
# 824  https://rickandmortyapi.com/api/character/avat...              1
# 825  https://rickandmortyapi.com/api/character/avat...              1
#
#      origin_id                    origin_name origin_type  \
# 0          1.0                  Earth (C-137)      Planet
# 1          NaN                            NaN         NaN
# 2         20.0  Earth (Replacement Dimension)      Planet
# 3         20.0  Earth (Replacement Dimension)      Planet
# 4         20.0  Earth (Replacement Dimension)      Planet
# ..         ...                            ...         ...
# 821       30.0      Earth (Unknown dimension)      Planet
# 822       30.0      Earth (Unknown dimension)      Planet
# 823       30.0      Earth (Unknown dimension)      Planet
# 824       30.0      Earth (Unknown dimension)      Planet
# 825       20.0  Earth (Replacement Dimension)      Planet
#
#           origin_dimension  origin_resident_count  loc_id  \
# 0          Dimension C-137                   27.0     3.0
# 1                      NaN                    NaN     3.0
# 2    Replacement Dimension                  230.0    20.0
# 3    Replacement Dimension                  230.0    20.0
# 4    Replacement Dimension                  230.0    20.0
# ..                     ...                    ...     ...
# 821                unknown                    4.0    30.0
# 822                unknown                    4.0    30.0
# 823                unknown                    4.0    30.0
# 824                unknown                    4.0    30.0
# 825  Replacement Dimension                  230.0    20.0
#
#                           loc_name       loc_type          loc_dimension  \
# 0                 Citadel of Ricks  Space station                unknown
# 1                 Citadel of Ricks  Space station                unknown
# 2    Earth (Replacement Dimension)         Planet  Replacement Dimension
# 3    Earth (Replacement Dimension)         Planet  Replacement Dimension
# 4    Earth (Replacement Dimension)         Planet  Replacement Dimension
# ..                             ...            ...                    ...
# 821      Earth (Unknown dimension)         Planet                unknown
# 822      Earth (Unknown dimension)         Planet                unknown
# 823      Earth (Unknown dimension)         Planet                unknown
# 824      Earth (Unknown dimension)         Planet                unknown
# 825  Earth (Replacement Dimension)         Planet  Replacement Dimension
#
#      loc_resident_count
# 0                 101.0
# 1                 101.0
# 2                 230.0
# 3                 230.0
# 4                 230.0
# ..                  ...
# 821                 4.0
# 822                 4.0
# 823                 4.0
# 824                 4.0
# 825               230.0
#
# [826 rows x 20 columns]

# %%
with pd.ExcelWriter("13.Rick and Morty API Data.xlsx", mode="a", engine="openpyxl") as writer:
    merged_df.to_excel(writer, sheet_name="MergedData", index=False)
