# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


dataset_as_given = pd.read_csv(r"d:\Desktop\Practice Python\21.gym_members_exercise_tracking.csv")

# %%
dataset_as_given
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %%
# Get column names
column_names = dataset_as_given.columns
print(column_names)
# Out:
# Index(['Age', 'Gender', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM',
#        'Resting_BPM', 'Session_Duration (hours)', 'Calories_Burned',
#        'Workout_Type', 'Fat_Percentage', 'Water_Intake (liters)',
#        'Workout_Frequency (days/week)', 'Experience_Level', 'BMI'],
#       dtype='object')

# %%
# Using describe() to calculate summary statistics
basic_stats = dataset_as_given.describe()
print(basic_stats)
# Out:
#               Age  Weight (kg)  Height (m)     Max_BPM     Avg_BPM  \
# count  973.000000   973.000000   973.00000  973.000000  973.000000
# mean    38.683453    73.854676     1.72258  179.883864  143.766701
# std     12.180928    21.207500     0.12772   11.525686   14.345101
# min     18.000000    40.000000     1.50000  160.000000  120.000000
# 25%     28.000000    58.100000     1.62000  170.000000  131.000000
# 50%     40.000000    70.000000     1.71000  180.000000  143.000000
# 75%     49.000000    86.000000     1.80000  190.000000  156.000000
# max     59.000000   129.900000     2.00000  199.000000  169.000000
#
#        Resting_BPM  Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# count   973.000000                973.000000       973.000000      973.000000
# mean     62.223022                  1.256423       905.422405       24.976773
# std       7.327060                  0.343033       272.641516        6.259419
# ...

# %%
desired = ["Age", "Weight (kg)", "Height (m)", "Max_BPM", "Avg_BPM", "Resting_BPM", 
           "Session_Duration (hours)", "Calories_Burned", "Fat_Percentage", "Water_Intake (liters)", "Workout_Frequency (days/week)", "Experience_Level", "BMI"]

dataset_as_given_numeric = dataset_as_given[desired]
# Calculating mean, median, and mode
mean_values = dataset_as_given_numeric.mean()
median_values = dataset_as_given_numeric.median()
mode_values = dataset_as_given_numeric.mode().iloc[0] 

print("Means for numerical columns in dataset:")
print(mean_values)
print("Medians for numerical columns in dataset:")
print(median_values)
print("Modes for numerical columns in dataset:")
print(mode_values)
# Out:
# Means for numerical columns in dataset:
# Age                               38.683453
# Weight (kg)                       73.854676
# Height (m)                         1.722580
# Max_BPM                          179.883864
# Avg_BPM                          143.766701
# Resting_BPM                       62.223022
# Session_Duration (hours)           1.256423
# Calories_Burned                  905.422405
# Fat_Percentage                    24.976773
# Water_Intake (liters)              2.626619
# Workout_Frequency (days/week)      3.321686
# Experience_Level                   1.809866
# BMI                               24.912127
# dtype: float64
# Medians for numerical columns in dataset:
# Age                               40.00
# Weight (kg)                       70.00
# Height (m)                         1.71
# Max_BPM                          180.00
# Avg_BPM                          143.00
# Resting_BPM                       62.00
# Session_Duration (hours)           1.26
# ...

# %%
# Calculating correlation between columns
correlation_numerical_columns = dataset_as_given_numeric.corr()
print(correlation_numerical_columns)
# Out:
#                                     Age  Weight (kg)  Height (m)   Max_BPM  \
# Age                            1.000000    -0.036340   -0.027837 -0.017073
# Weight (kg)                   -0.036340     1.000000    0.365321  0.057061
# Height (m)                    -0.027837     0.365321    1.000000 -0.017660
# Max_BPM                       -0.017073     0.057061   -0.017660  1.000000
# Avg_BPM                        0.035969     0.009717   -0.014776 -0.039751
# Resting_BPM                    0.004354    -0.032138   -0.005090  0.036647
# Session_Duration (hours)      -0.019912    -0.013666   -0.010206  0.010051
# Calories_Burned               -0.154679     0.095443    0.086348  0.002090
# Fat_Percentage                 0.002370    -0.225512   -0.235521 -0.009056
# Water_Intake (liters)          0.041528     0.394276    0.393533  0.031621
# Workout_Frequency (days/week)  0.008055    -0.011769   -0.011270 -0.029099
# ...

# %%
#Correlation matrix - visual
matrix = correlation_numerical_columns.corr()

plt.figure(figsize=(8,6))
sns.heatmap(matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
# Calculating variance and standard deviation
variance_val = correlation_numerical_columns.var()
std_dev_val = correlation_numerical_columns.std()

print("Variance for numerical columns in dataset:")
print(variance_val)
print("Standard Deviation for numerical columns in dataset:")
print(std_dev_val)
# Out:
# Variance for numerical columns in dataset:
# Age                              0.081718
# Weight (kg)                      0.134808
# Height (m)                       0.103126
# Max_BPM                          0.076793
# Avg_BPM                          0.080907
# Resting_BPM                      0.077390
# Session_Duration (hours)         0.213511
# Calories_Burned                  0.200203
# Fat_Percentage                   0.197604
# Water_Intake (liters)            0.126042
# Workout_Frequency (days/week)    0.186202
# Experience_Level                 0.218748
# BMI                              0.128762
# dtype: float64
# Standard Deviation for numerical columns in dataset:
# Age                              0.285864
# Weight (kg)                      0.367162
# Height (m)                       0.321133
# Max_BPM                          0.277115
# Avg_BPM                          0.284442
# Resting_BPM                      0.278191
# Session_Duration (hours)         0.462072
# ...

# %%
# Calculating skewness and kurtosis
skewness_val = correlation_numerical_columns.skew()
kurtosis_val = correlation_numerical_columns.kurt()

print("Skewness for numerical columns in dataset:")
print(skewness_val)
print("Kurtosis for numerical columns in dataset:")
print(kurtosis_val)

# %% [markdown]
# Next thing would be to create various plots. Then test for normality
