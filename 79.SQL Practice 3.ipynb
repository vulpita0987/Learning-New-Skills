# %%
import pandas as pd

data = [
    {
        "Question": "1. Return all patients older than 40.",
        "Options": "A: SELECT * FROM Patients WHERE age >= 40;\n"
                   "B: SELECT * FROM Patients WHERE age > 40;\n"
                   "C: SELECT * FROM Patients HAVING age > 40;\n"
                   "D: SELECT age FROM Patients WHERE age > 40;",
        "Your Answer": "B",
        "Correct Answer": "B",
        "Result": "Correct"
    },
    {
        "Question": "2. Names of patients whose name starts with 'M'.",
        "Options": "A: SELECT name FROM Patients WHERE name LIKE '%M%';\n"
                   "B: SELECT name FROM Patients WHERE name LIKE 'M%';\n"
                   "C: SELECT name FROM Patients WHERE name = 'M';\n"
                   "D: SELECT name FROM Patients WHERE name LIKE '%M';",
        "Your Answer": "B",
        "Correct Answer": "B",
        "Result": "Correct"
    },
    {
        "Question": "3. Appointments with status Completed or No‑Show.",
        "Options": "A: SELECT * FROM Appointments WHERE status = 'Completed' OR 'No-Show';\n"
                   "B: SELECT * FROM Appointments WHERE status IN ('Completed','No-Show');\n"
                   "C: SELECT * FROM Appointments WHERE status LIKE 'Completed|No-Show';\n"
                   "D: SELECT * FROM Appointments WHERE status != 'Cancelled';",
        "Your Answer": "B",
        "Correct Answer": "B",
        "Result": "Correct"
    },
    {
        "Question": "4. All patients sorted alphabetically.",
        "Options": "A: SELECT * FROM Patients SORT BY name;\n"
                   "B: SELECT * FROM Patients ORDER name ASC;\n"
                   "C: SELECT * FROM Patients ORDER BY name ASC;\n"
                   "D: SELECT name FROM Patients;",
        "Your Answer": "C",
        "Correct Answer": "C",
        "Result": "Correct"
    },
    {
        "Question": "5. Appointments in January 2024.",
        "Options": "A: SELECT * FROM Appointments WHERE appointment_date LIKE '2024-01%';\n"
                   "B: SELECT * FROM Appointments WHERE appointment_date BETWEEN '2024-01-01' AND '2024-01-31';\n"
                   "C: Both A and B\n"
                   "D: Neither",
        "Your Answer": "C",
        "Correct Answer": "C",
        "Result": "Correct"
    },
    {
        "Question": "6. Appointment with patient name + age.",
        "Options": "A: SELECT name, age FROM Patients;\n"
                   "B: SELECT Patients.name, Patients.age, Appointments.* FROM Patients;\n"
                   "C: SELECT Patients.name, Patients.age, Appointments.appointment_date FROM Appointments JOIN Patients ON Appointments.patient_id = Patients.patient_id;\n"
                   "D: SELECT * FROM Appointments;",
        "Your Answer": "C",
        "Correct Answer": "C",
        "Result": "Correct"
    },
    {
        "Question": "7. All patients + diagnoses (even if none).",
        "Options": "A: SELECT * FROM Patients JOIN Diagnoses ON Patients.patient_id = Diagnoses.patient_id;\n"
                   "B: SELECT * FROM Patients LEFT JOIN Diagnoses ON Patients.patient_id = Diagnoses.patient_id;\n"
                   "C: SELECT * FROM Diagnoses LEFT JOIN Patients ON Patients.patient_id = Diagnoses.patient_id;\n"
                   "D: SELECT * FROM Patients WHERE diagnosis IS NULL;",
        "Your Answer": "A",
        "Correct Answer": "B",
        "Result": "Incorrect"
    },
    {
        "Question": "8. Patients with at least one completed appointment.",
        "Options": "A: SELECT name FROM Patients;\n"
                   "B: SELECT DISTINCT Patients.name FROM Patients JOIN Appointments ON Patients.patient_id = Appointments.patient_id WHERE status = 'Completed';\n"
                   "C: SELECT Patients.name FROM Patients WHERE status = 'Completed';\n"
                   "D: SELECT * FROM Appointments;",
        "Your Answer": "B",
        "Correct Answer": "B",
        "Result": "Correct"
    },
    {
        "Question": "9. Diagnosis + patient gender.",
        "Options": "A: SELECT diagnosis, gender FROM Diagnoses;\n"
                   "B: SELECT diagnosis, gender FROM Diagnoses JOIN Patients ON Diagnoses.patient_id = Patients.patient_id;\n"
                   "C: SELECT * FROM Patients;\n"
                   "D: SELECT gender FROM Patients;",
        "Your Answer": "A",
        "Correct Answer": "B",
        "Result": "Incorrect"
    },
    {
        "Question": "10. Appointments + patient name + diagnosis.",
        "Options": "A: SELECT * FROM Patients;\n"
                   "B: SELECT Patients.name, Appointments.*, Diagnoses.diagnosis FROM Patients LEFT JOIN Appointments ON Patients.patient_id = Appointments.patient_id LEFT JOIN Diagnoses ON Patients.patient_id = Diagnoses.patient_id;\n"
                   "C: SELECT * FROM Appointments JOIN Diagnoses;\n"
                   "D: SELECT diagnosis FROM Diagnoses;",
        "Your Answer": "B",
        "Correct Answer": "B",
        "Result": "Correct"
    },
    {
        "Question": "11. Count appointments per patient.",
        "Options": "A: SELECT name, COUNT(*) FROM Patients;\n"
                   "B: SELECT Patients.name, COUNT(Appointments.appointment_id) FROM Patients LEFT JOIN Appointments ON Patients.patient_id = Appointments.patient_id GROUP BY Patients.name;\n"
                   "C: SELECT COUNT(*) FROM Appointments;\n"
                   "D: SELECT * FROM Patients;",
        "Your Answer": "B",
        "Correct Answer": "B",
        "Result": "Correct"
    },
    {
        "Question": "12. Count diagnoses per patient.",
        "Options": "A: SELECT name, COUNT(*) FROM Diagnoses;\n"
                   "B: SELECT Patients.name, COUNT(Diagnoses.diagnosis_id) FROM Patients LEFT JOIN Diagnoses ON Patients.patient_id = Diagnoses.patient_id GROUP BY Patients.name;\n"
                   "C: SELECT * FROM Diagnoses;\n"
                   "D: SELECT COUNT(*) FROM Patients;",
        "Your Answer": "B",
        "Correct Answer": "B",
        "Result": "Correct"
    },
    {
        "Question": "13. Count appointments by status.",
        "Options": "A: SELECT status, COUNT(*) FROM Appointments GROUP BY status;\n"
                   "B: SELECT COUNT(status) FROM Appointments;\n"
                   "C: SELECT * FROM Appointments;\n"
                   "D: SELECT status FROM Appointments;",
        "Your Answer": "A",
        "Correct Answer": "A",
        "Result": "Correct"
    },
    {
        "Question": "14. Earliest appointment per patient.",
        "Options": "A: SELECT name, MIN(appointment_date) FROM Patients;\n"
                   "B: SELECT Patients.name, MIN(Appointments.appointment_date) FROM Patients LEFT JOIN Appointments ON Patients.patient_id = Appointments.patient_id GROUP BY Patients.name;\n"
                   "C: SELECT MIN(appointment_date) FROM Appointments;\n"
                   "D: SELECT * FROM Appointments;",
        "Your Answer": "B",
        "Correct Answer": "B",
        "Result": "Correct"
    },
    {
        "Question": "15. Label patients by age group.",
        "Options": "A: SELECT name, age, IF(age < 40, 'Young', 'Old') FROM Patients;\n"
                   "B: SELECT name, age, CASE WHEN age < 40 THEN 'Young' WHEN age BETWEEN 40 AND 55 THEN 'Middle' ELSE 'Senior' END FROM Patients;\n"
                   "C: SELECT name FROM Patients;\n"
                   "D: SELECT * FROM Patients;",
        "Your Answer": "B",
        "Correct Answer": "B",
        "Result": "Correct"
    }
]

df = pd.DataFrame(data)
df
