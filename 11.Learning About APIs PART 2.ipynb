# %% [markdown]
# REST API </br>
# REST = Representational State Transfer -> communicating over the web (interent)</br>
# API = Application Programming Interface (a way two pieces of software can communicate with one another)</br>
# You will be getting JSON data</br>
# JSON - JavaScript Object Notation</br>
# End Points -> spcific URL where an API receives requests and sends responses</br>
# Exposed API endpoints can be used to retrive data through and API from a Server</br>
# APIs are used to get two different applications to talk -> connecting directly to the database would create security concerns</br>
# The backend can change - such as the programming language used for an application can change all together - and the API can continue having the exposed endpoint - allowing the part of the application that the user sees AKA the front end to not be affected due to the API use - that extracts the required data regardless of the programming language</br>
# Allows for multiple people to access data and create new apps from the data - allowing the data to be consumed</br>
# GET is used to retrive data from the server</br>
# POST is used to write data</br>
# DELETE is used to delete data</br>
# PUT is used to update data</br>
# CRUD operations -> Create, Read, Update, Delete</br>
# PATCH can be used to UPDATE sections of a data entry</br>
# 00:20:51 -> Video Time

# %%
#https://api.stackexchange.com/2.2/answers?order=desc&sort=activity&site=stackoverflow

import requests
import json

# %%
response = requests.get('http://api.stackexchange.com/2.2/questions?order=desc&sort=activity&site=stackoverflow')
print(response)
# Out:
# <Response [200]>

# %%
print(response.json())
# Out:
# {'items': [{'tags': ['mongodb', 'terraform'], 'owner': {'reputation': 1, 'user_id': 10240905, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/0835ef3a0c21764dc4e2740b1846d1fb?s=256&d=identicon&r=PG&f=y&so-version=2', 'display_name': 'nat', 'link': 'https://stackoverflow.com/users/10240905/nat'}, 'is_answered': False, 'view_count': 14, 'answer_count': 2, 'score': 0, 'last_activity_date': 1768419351, 'creation_date': 1768321520, 'question_id': 79867138, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/79867138/deprecation-of-dynamodb-table-in-terraform-s3-backend', 'title': 'Deprecation of dynamodb_table in Terraform S3 Backend'}, {'tags': ['grafana', 'grafana-loki'], 'owner': {'reputation': 1766, 'user_id': 826046, 'user_type': 'registered', 'accept_rate': 70, 'profile_image': 'https://www.gravatar.com/avatar/498ff1380b82b62223dae8ea8f9ad10d?s=256&d=identicon&r=PG', 'display_name': 'Sagar Nikam', 'link': 'https://stackoverflo
# ...

# %%
print(response.json()['items'])
# Out:
# [{'tags': ['mongodb', 'terraform'], 'owner': {'reputation': 1, 'user_id': 10240905, 'user_type': 'registered', 'profile_image': 'https://www.gravatar.com/avatar/0835ef3a0c21764dc4e2740b1846d1fb?s=256&d=identicon&r=PG&f=y&so-version=2', 'display_name': 'nat', 'link': 'https://stackoverflow.com/users/10240905/nat'}, 'is_answered': False, 'view_count': 14, 'answer_count': 2, 'score': 0, 'last_activity_date': 1768419351, 'creation_date': 1768321520, 'question_id': 79867138, 'content_license': 'CC BY-SA 4.0', 'link': 'https://stackoverflow.com/questions/79867138/deprecation-of-dynamodb-table-in-terraform-s3-backend', 'title': 'Deprecation of dynamodb_table in Terraform S3 Backend'}, {'tags': ['grafana', 'grafana-loki'], 'owner': {'reputation': 1766, 'user_id': 826046, 'user_type': 'registered', 'accept_rate': 70, 'profile_image': 'https://www.gravatar.com/avatar/498ff1380b82b62223dae8ea8f9ad10d?s=256&d=identicon&r=PG', 'display_name': 'Sagar Nikam', 'link': 'https://stackoverflow.com/user
# ...

# %%
for data in response.json()['items']:
    print(data['title'])
    print(data['link'])
    print()
# Out:
# Deprecation of dynamodb_table in Terraform S3 Backend
# https://stackoverflow.com/questions/79867138/deprecation-of-dynamodb-table-in-terraform-s3-backend
#
# caller=spanlogger.go:152 middleware=QueryShard.astMapperware org_id=fake user=fake level=warn msg=&quot;failed mapping AST&quot; err=&quot;context canceled&quot;
# https://stackoverflow.com/questions/79862238/caller-spanlogger-go152-middleware-queryshard-astmapperware-org-id-fake-user-fa
#
# Expose EKS kubernetes dashboard via domain
# https://stackoverflow.com/questions/79868049/expose-eks-kubernetes-dashboard-via-domain
#
# 3D object rotation issue
# https://stackoverflow.com/questions/78521903/3d-object-rotation-issue
#
# Reply to message as threaded response in MS Teams using Azure Bot Sevices
# https://stackoverflow.com/questions/61970671/reply-to-message-as-threaded-response-in-ms-teams-using-azure-bot-sevices
#
# Unwanted cell selection in DataGridView when closing ContexMenuStrip
# ...

# %%
for data in response.json()['items']:
    if data['answer_count'] == 0:
       print(data['title'])
       print(data['link'])
       
    else:
        print("skipped")
        print()
# Out:
# skipped
#
# skipped
#
# Expose EKS kubernetes dashboard via domain
# https://stackoverflow.com/questions/79868049/expose-eks-kubernetes-dashboard-via-domain
# skipped
#
# skipped
#
# Unwanted cell selection in DataGridView when closing ContexMenuStrip
# https://stackoverflow.com/questions/79867949/unwanted-cell-selection-in-datagridview-when-closing-contexmenustrip
# skipped
#
# Implementing remember-me/stay logged in logic in a Servlet
# https://stackoverflow.com/questions/79868048/implementing-remember-me-stay-logged-in-logic-in-a-servlet
# EhCache version upgrade from 2.10 to 3.10.8
# https://stackoverflow.com/questions/79865658/ehcache-version-upgrade-from-2-10-to-3-10-8
# skipped
#
# cross-origin-opener-policy error using localhost in Blazor WASM
# https://stackoverflow.com/questions/79868046/cross-origin-opener-policy-error-using-localhost-in-blazor-wasm
# About GWLP_USERDATA
# https://stackoverflow.com/questions/79868045/about-gwlp-userdata
# skipped
#
# skipped
#
# skipped
#
# ...
