# %%
# SQL Practice Log – Full Day Summary
# Includes BOTH quizzes: Intermediate (15 questions) + Beginner (10 questions)
# Each entry contains: question, options, your answer, correctness

sql_practice_log = [
    # -------------------------
    # INTERMEDIATE QUIZ (15 Qs)
    # -------------------------
    {
        "question": "Which query returns all customers who have placed at least one order?",
        "options": [
            "A) SELECT * FROM customers WHERE id IN (SELECT customer_id FROM orders);",
            "B) SELECT * FROM customers WHERE EXISTS customers.id = orders.customer_id;",
            "C) SELECT customers.* FROM customers JOIN orders;",
            "D) SELECT * FROM customers HAVING COUNT(orders.id) > 0;"
        ],
        "your_answer": "A",
        "correct": True
    },
    {
        "question": "Which query returns the total number of orders per customer?",
        "options": [
            "A) SELECT customer_id, COUNT(*) FROM orders;",
            "B) SELECT customer_id, COUNT(*) FROM orders GROUP BY customer_id;",
            "C) SELECT customer_id, SUM(*) FROM orders GROUP BY customer_id;",
            "D) SELECT customer_id FROM orders GROUP BY customer_id HAVING COUNT(*) > 1;"
        ],
        "your_answer": "B",
        "correct": True
    },
    {
        "question": "Which query returns products priced between 10 and 50?",
        "options": [
            "A) SELECT * FROM products HAVING price BETWEEN 10 AND 50;",
            "B) SELECT * FROM products WHERE price >= 10 OR price <= 50;",
            "C) SELECT * FROM products WHERE price BETWEEN 10 AND 50;",
            "D) SELECT * FROM products WHERE price IN RANGE 10 TO 50;"
        ],
        "your_answer": "C",
        "correct": True
    },
    {
        "question": "Which query returns all employees who do not have a manager assigned?",
        "options": [
            "A) SELECT * FROM employees WHERE manager_id IS NULL;",
            "B) SELECT * FROM employees WHERE manager_id <> NULL;",
            "C) SELECT * FROM employees WHERE manager_id = NULL;",
            "D) SELECT * FROM employees HAVING manager_id IS NULL;"
        ],
        "your_answer": "A",
        "correct": True
    },
    {
        "question": "Which query returns the highest salary in the company?",
        "options": [
            "A) SELECT salary MAX FROM employees;",
            "B) SELECT TOP salary FROM employees;",
            "C) SELECT HIGHEST(salary) FROM employees;",
            "D) SELECT MAX(salary) FROM employees;"
        ],
        "your_answer": "D",
        "correct": True
    },
    {
        "question": "Which query returns all orders along with the customer name?",
        "options": [
            "A) SELECT o.*, c.name FROM orders o MATCH customers c;",
            "B) SELECT o.*, c.name FROM orders o JOIN customers c ON o.customer_id = c.id;",
            "C) SELECT o.*, c.name FROM orders o CONNECT customers c;",
            "D) SELECT * FROM orders, customers;"
        ],
        "your_answer": "B",
        "correct": True
    },
    {
        "question": "Which query returns the number of employees in each department, but only departments with more than 5 employees?",
        "options": [
            "A) SELECT department, COUNT(*) FROM employees GROUP BY department HAVING COUNT(*) > 5;",
            "B) SELECT department FROM employees GROUP BY department WHERE COUNT(*) > 5;",
            "C) SELECT department, COUNT(*) FROM employees HAVING COUNT(*) > 5;",
            "D) SELECT department, COUNT(*) FROM employees WHERE COUNT(*) > 5;"
        ],
        "your_answer": "A",
        "correct": True
    },
    {
        "question": "Which query returns customers whose names start with 'A'?",
        "options": [
            "A) SELECT * FROM customers HAVING name LIKE 'A%';",
            "B) SELECT * FROM customers WHERE name = 'A*';",
            "C) SELECT * FROM customers WHERE name LIKE 'A%';",
            "D) SELECT * FROM customers WHERE name MATCH 'A*';"
        ],
        "your_answer": "C",
        "correct": True
    },
    {
        "question": "Which query deletes all rows where the phone number is NULL?",
        "options": [
            "A) DELETE customers WHERE phone IS NULL;",
            "B) DELETE FROM customers WHERE phone IS NULL;",
            "C) REMOVE FROM customers WHERE phone IS NULL;",
            "D) DELETE FROM customers HAVING phone IS NULL;"
        ],
        "your_answer": "B",
        "correct": True
    },
    {
        "question": "Which query returns the average order value per customer?",
        "options": [
            "A) SELECT customer_id, AVG(amount) FROM orders;",
            "B) SELECT AVG(amount) FROM orders GROUP BY customer_id HAVING amount > 0;",
            "C) SELECT customer_id FROM orders GROUP BY customer_id AVG(amount);",
            "D) SELECT customer_id, AVG(amount) FROM orders GROUP BY customer_id;"
        ],
        "your_answer": "D",
        "correct": True
    },
    {
        "question": "Which query returns all products that have never been ordered?",
        "options": [
            "A) SELECT products.* FROM products JOIN order_items;",
            "B) SELECT * FROM products WHERE id NOT IN order_items.product_id;",
            "C) SELECT * FROM products MATCH order_items;",
            "D) SELECT * FROM products p LEFT JOIN order_items oi ON p.id = oi.product_id WHERE oi.product_id IS NULL;"
        ],
        "your_answer": "D",
        "correct": True
    },
    {
        "question": "Which query returns the total revenue for each month?",
        "options": [
            "A) SELECT MONTH(order_date), SUM(amount) FROM orders GROUP BY MONTH(order_date);",
            "B) SELECT SUM(amount) FROM orders GROUP BY order_date;",
            "C) SELECT MONTH(order_date), SUM(amount) FROM orders;",
            "D) SELECT MONTH(order_date) FROM orders HAVING SUM(amount);"
        ],
        "your_answer": "A",
        "correct": True
    },
    {
        "question": "Which query returns all employees sorted by hire date from oldest to newest?",
        "options": [
            "A) SELECT * FROM employees ORDER hire_date FIRST;",
            "B) SELECT * FROM employees ORDER BY hire_date ASC;",
            "C) SELECT * FROM employees SORT BY hire_date ASC;",
            "D) SELECT * FROM employees SORT hire_date UP;"
        ],
        "your_answer": "B",
        "correct": True
    },
    {
        "question": "Which query returns the count of NULL emails?",
        "options": [
            "A) SELECT COUNT(*) FROM users WHERE email IS NULL;",
            "B) SELECT COUNT(email) FROM users WHERE email = NULL;",
            "C) SELECT COUNT(email) FROM users HAVING email IS NULL;",
            "D) SELECT COUNT(NULL) FROM users;"
        ],
        "your_answer": "A",
        "correct": True
    },
    {
        "question": "Which query returns all orders placed in 2024?",
        "options": [
            "A) SELECT * FROM orders WHERE YEAR(order_date) IN 2024;",
            "B) SELECT * FROM orders HAVING YEAR(order_date) = 2024;",
            "C) SELECT * FROM orders WHERE order_date LIKE '%2024%';",
            "D) SELECT * FROM orders WHERE YEAR(order_date) = 2024;"
        ],
        "your_answer": "D",
        "correct": True
    },

    # -------------------------
    # BEGINNER QUIZ (10 Qs)
    # -------------------------
    {
        "question": "Which query selects all rows from the table `books`?",
        "options": [
            "A) SHOW * books;",
            "B) SELECT * FROM books;",
            "C) GET ALL FROM books;",
            "D) SELECT books;"
        ],
        "your_answer": "B",
        "correct": True
    },
    {
        "question": "Which query returns only the `title` column from the `movies` table?",
        "options": [
            "A) SELECT title FROM movies;",
            "B) SELECT movies.title;",
            "C) GET title IN movies;",
            "D) FETCH movies(title);"
        ],
        "your_answer": "A",
        "correct": True
    },
    {
        "question": "Which query returns rows where `quantity` is greater than 5?",
        "options": [
            "A) SELECT stock WHERE quantity > 5;",
            "B) GET * FROM stock WHEN quantity > 5;",
            "C) SELECT * FROM stock WHERE quantity > 5;",
            "D) SELECT * FROM stock HAVING quantity > 5;"
        ],
        "your_answer": "C",
        "correct": True
    },
    {
        "question": "Which query returns unique values from the `category` column?",
        "options": [
            "A) SELECT DISTINCT category FROM items;",
            "B) SELECT category ONLY FROM items;",
            "C) SELECT category FROM items GROUP UNIQUE;",
            "D) SELECT UNIQUE category FROM items;"
        ],
        "your_answer": "A",
        "correct": True
    },
    {
        "question": "Which query sorts customers by `last_name` alphabetically?",
        "options": [
            "A) SELECT * FROM customers SORT BY last_name ASC;",
            "B) SELECT * FROM customers SORT last_name UP;",
            "C) SELECT * FROM customers ORDER last_name FIRST;",
            "D) SELECT * FROM customers ORDER BY last_name ASC;"
        ],
        "your_answer": "D",
        "correct": True
    },
    {
        "question": "Which query finds rows where `email` contains 'shop'?",
        "options": [
            "A) SELECT * FROM users WHERE email LIKE '%shop%';",
            "B) SELECT * FROM users WHERE email = '*shop*';",
            "C) SELECT * FROM users WHERE email MATCH '*shop*';",
            "D) SELECT * FROM users HAVING email LIKE '%shop%';"
        ],
        "your_answer": "A",
        "correct": True
    },
    {
        "question": "Which query inserts a new row with only a `name` into `tags`?",
        "options": [
            "A) ADD INTO tags name = 'New';",
            "B) INSERT INTO tags (name) VALUES ('New');",
            "C) INSERT name INTO tags VALUES ('New');",
            "D) PUT INTO tags VALUES name='New';"
        ],
        "your_answer": "B",
        "correct": True
    },
    {
        "question": "Which query deletes rows where `archived` is false?",
        "options": [
            "A) REMOVE FROM logs WHERE archived = false;",
            "B) DELETE FROM logs HAVING archived = false;",
            "C) DELETE FROM logs WHERE archived = false;",
            "D) DELETE logs WHERE archived = false;"
        ],
        "your_answer": "C",
        "correct": True
    },
    {
        "question": "Which query updates the `status` of order 12 to 'shipped'?",
        "options": [
            "A) UPDATE orders SET status = 'shipped' WHERE id = 12;",
            "B) MODIFY orders status = 'shipped' WHEN id = 12;",
            "C) SET status = 'shipped' IN orders WHERE id = 12;",
            "D) CHANGE orders SET status = 'shipped' IF id = 12;"
        ],
        "your_answer": "A",
        "correct": True
    },
    {
        "question": "Which query counts all rows in the `tickets` table?",
        "options": [
            "A) SELECT COUNT(*) FROM tickets;",
            "B) GET COUNT tickets;",
            "C) SELECT TOTAL(tickets) FROM tickets;",
            "D) COUNT * FROM tickets;"
        ],
        "your_answer": "A",
        "correct": True
    }
]

sql_practice_log
# Out:
# {'Q1': {'question': 'Select all female patients.',
#   'answer': "\nSELECT *\nFROM Patients\nWHERE gender = 'F';\n"},
#  'Q2': {'question': 'Count how many appointments were completed.',
#   'answer': "\nSELECT COUNT(*) AS completed_count\nFROM Appointments\nWHERE status = 'Completed';\n"},
#  'Q3': {'question': 'List all appointments with the patient’s name.',
#   'answer': '\nSELECT \n    Patients.name AS PatientName,\n    Appointments.appointment_date AS AppointmentDate,\n    Appointments.status AS Status\nFROM Appointments\nJOIN Patients \n    ON Appointments.patient_id = Patients.patient_id;\n'},
#  'Q4': {'question': 'Find patients who have never had an appointment.',
#   'answer': '\nSELECT Patients.name\nFROM Patients\nLEFT JOIN Appointments \n    ON Patients.patient_id = Appointments.patient_id\nWHERE Appointments.patient_id IS NULL;\n'},
#  'Q5': {'question': 'Count appointments per patient.',
# ...
